# %% [markdown]
# # Breast Histopathology Images

# %%
import os
import zipfile
import random
import shutil
import glob
import numpy as np
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from shutil import copyfile
from PIL import Image

# %% [markdown]
# ## Pre-procesamiento

# %%
breast_imgs = glob.glob('breast-histopathology-images/IDC_regular_ps50_idx5/**/**.png', recursive = True)

# %%
for imgname in breast_imgs[:5]:
    print(imgname)
# Out:
# breast-histopathology-images/IDC_regular_ps50_idx5\10253\0\10253_idx5_x1001_y1001_class0.png
# breast-histopathology-images/IDC_regular_ps50_idx5\10253\0\10253_idx5_x1001_y1051_class0.png
# breast-histopathology-images/IDC_regular_ps50_idx5\10253\0\10253_idx5_x1001_y1101_class0.png
# breast-histopathology-images/IDC_regular_ps50_idx5\10253\0\10253_idx5_x1001_y1151_class0.png
# breast-histopathology-images/IDC_regular_ps50_idx5\10253\0\10253_idx5_x1001_y1201_class0.png

# %% [markdown]
# Si dejamos "shutil.copy" crearemos un duplicado de las imágenes en las carpetas especificadas, lo cual no es recomendable correr si ya lo hicimos una vez

# %%
non_cancer_imgs = []
cancer_imgs = []

for img in breast_imgs:
    if img[-5] == '0':
        non_cancer_imgs.append(img)
    elif img[-5] == '1':
        cancer_imgs.append(img)

# Seleccionar una muestra equilibrada de imágenes sin cáncer
random.seed(1)
non_cancer_sample = random.sample(non_cancer_imgs, min(len(non_cancer_imgs), 88786))

non_cancer_num = len(non_cancer_sample)
cancer_num = len(cancer_imgs) 
total_img_num = non_cancer_num + cancer_num

# Mostrar 
print('Número de imágenes sin cáncer: {}'.format(non_cancer_num))
print('Número de imágenes con cáncer: {}'.format(cancer_num))
print('Total de imágenes: {}'.format(total_img_num))
# Out:
# Número de imágenes sin cáncer: 88786
# Número de imágenes con cáncer: 78786
# Total de imágenes: 167572

# %%
carpeta_nocancer = 'no-cancer/'

for img in non_cancer_sample:
    shutil.copy(img, carpeta_nocancer)

# %%
carpeta_cancer = 'cancer/'

for img in cancer_imgs:
    shutil.copy(img, carpeta_cancer)

# %%
imagenes_carpeta_cancer = glob.glob('cancer/**.png', recursive = True)
imagenes_carpeta_nocancer = glob.glob('no-cancer/**.png', recursive = True)

print('Imágenes de carpeta cancer: {}' .format(len(imagenes_carpeta_cancer)))
print('Imágenes de carpeta no-cancer: {}' .format(len(imagenes_carpeta_nocancer)))
# Out:
# Imágenes de carpeta cancer: 88786
# Imágenes de carpeta no-cancer: 88786

# %%
random.seed(1)
cancer_sample = random.sample(cancer_imgs, 11214)
# Configuración del generador de datos
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)
# Generar imágenes aumentadas y guardarlas en el directorio de salida
for img_path in cancer_sample:
    img = Image.open(img_path)  
    img = img.resize((50, 50))  
    img_array = np.array(img)
    img_array = img_array.reshape((1,) + img_array.shape)

    i = 0
    for batch in datagen.flow(img_array, batch_size=1, 
                              save_to_dir=carpeta_cancer, 
                              save_prefix='mod',
                              save_format='png'):
        i += 1
        if i >= 5:  
            break

print(f"Imágenes aumentadas guardadas en {carpeta_cancer}")
# Out:
# Imágenes aumentadas guardadas en cancer/

# %%
imagenes_carpeta_cancer = glob.glob('cancer/**.png', recursive = True)

print('Imágenes de carpeta cancer: {}' .format(len(imagenes_carpeta_cancer)))
# Out:
# Imágenes de carpeta cancer: 88786

# %%
non_cancer_num = len(non_cancer_imgs)  # No cancer
cancer_num = len(cancer_imgs)   # Cancer 
        
total_img_num = non_cancer_num + cancer_num
        
print('Número de imágenes sin cancer: {}' .format(non_cancer_num))   # images of Non cancer
print('Número de imágenes cancer : {}' .format(cancer_num))   # images of cancer 
print('Total de imágenes : {}' .format(total_img_num))
# Out:
# Número de imágenes sin cancer: 198738
# Número de imágenes cancer : 78786
# Total de imágenes : 277524

# %%
carpeta_nocancer = 'no-cancer/'
carpeta_cancer = 'cancer/'
entrenamiento_cancer = 'entrenamiento/cancer/'
entrenamiento_nocancer = 'entrenamiento/nocancer/'
test_cancer = 'test/cancer/'
test_nocancer = 'test/nocancer/'

# %%
def split_data(SOURCE, TRAINING, TESTING, SPLIT_SIZE):
    files = []
    for filename in os.listdir(SOURCE):
        file = SOURCE + filename
        if os.path.getsize(file) > 0:
            files.append(filename)
        else:
            print(filename + " is zero length, so ignoring.")

    training_length = int(len(files) * SPLIT_SIZE)
    testing_length = int(len(files) - training_length)
    shuffled_set = random.sample(files, len(files))
    training_set = shuffled_set[0:training_length]
    testing_set = shuffled_set[:testing_length]

    for filename in training_set:
        this_file = SOURCE + filename
        destination = TRAINING + filename
        copyfile(this_file, destination)

    for filename in testing_set:
        this_file = SOURCE + filename
        destination = TESTING + filename
        copyfile(this_file, destination)

# %% [markdown]
# Separamos los datos (imágenes) para entrenamiento y para test. Solo hacerlo una vez

# %%
split_size = .8
random.seed(1)
split_data(carpeta_cancer, entrenamiento_cancer, test_cancer, split_size)
split_data(carpeta_nocancer, entrenamiento_nocancer, test_nocancer, split_size)

# %%
entrenamiento_cancer = 'entrenamiento/cancer/'
entrenamiento_nocancer = 'entrenamiento/nocancer/'
test_cancer = 'test/cancer/'
test_nocancer = 'test/nocancer/'

datos_entrenamiento_cancer = glob.glob('entrenamiento/cancer/**.png', recursive = True)
datos_entrenamiento_nocancer = glob.glob('entrenamiento/nocancer/**.png', recursive = True)
datos_test_cancer = glob.glob('test/cancer/**.png', recursive = True)
datos_test_nocancer = glob.glob('test/nocancer/**.png', recursive = True)


print('Imágenes de entrenamiento sin cancer: {}' .format(len(datos_entrenamiento_cancer)))
print('Imágenes de entrenamiento con cancer: {}' .format(len(datos_entrenamiento_nocancer)))
print('Imágenes de entrenamiento total: {}' .format(len(datos_entrenamiento_nocancer)+len(datos_entrenamiento_cancer)))
print('Imágenes de test sin cancer: {}' .format(len(datos_test_cancer)))
print('Imágenes de test con cancer: {}' .format(len(datos_test_nocancer)))
print('Imágenes de test total: {}' .format(len(datos_test_nocancer)+len(datos_test_cancer)))
# Out:
# Imágenes de entrenamiento sin cancer: 71028
# Imágenes de entrenamiento con cancer: 71028
# Imágenes de entrenamiento total: 142056
# Imágenes de test sin cancer: 17758
# Imágenes de test con cancer: 17758
# Imágenes de test total: 35516

# %% [markdown]
# ## RNC
# Las imágenes proporcionadas en https://www.kaggle.com/datasets/paultimothymooney/breast-histopathology-images/data tienen una dimensión de 50x50 y están a color (RGB).

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3, 3), activation='relu', input_shape=(50, 50, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(optimizer=RMSprop(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
TRAINING_DIR = "entrenamiento/"
 
train_datagen = ImageDataGenerator(rescale=1./255,
      rotation_range=40,
      width_shift_range=0.1,
      height_shift_range=0.1,
      shear_range=0.1,
      zoom_range=0.2,
      horizontal_flip=True,
      fill_mode='nearest')

train_generator = train_datagen.flow_from_directory(TRAINING_DIR,
                                                    batch_size=100,
                                                    class_mode='binary',
                                                    target_size=(50, 50))

VALIDATION_DIR = "test/"

validation_datagen = ImageDataGenerator(rescale=1./255,
      rotation_range=40,
      width_shift_range=0.1,
      height_shift_range=0.1,
      shear_range=0.1,
      zoom_range=0.2,
      horizontal_flip=True,
      fill_mode='nearest')
validation_generator = validation_datagen.flow_from_directory(VALIDATION_DIR,
                                                              batch_size=100,
                                                              class_mode='binary',
                                                              target_size=(50, 50))
# Out:
# Found 142056 images belonging to 2 classes.
# Found 35516 images belonging to 2 classes.

# %%
total_muestras = len(train_generator)  
tamano_lote = train_generator.batch_size
numero_de_lotes = total_muestras // tamano_lote
print(total_muestras)
print(tamano_lote)
print(numero_de_lotes)
# Out:
# 1421
# 100
# 14

# %% [markdown]
# ### Modelo 1

# %%
checkpoint = ModelCheckpoint('Pesos/Modelo1/pesos_del_modelo_epoch_{epoch:02d}.h5', 
                             save_weights_only=True, 
                             save_best_only=False)

# %%
history = model.fit(train_generator,
                              steps_per_epoch= 100,
                              epochs=15,
                              verbose=1,
                              validation_data=validation_generator,
                              callbac
# 100/100 [==============================] - 51s 509ms/step - loss: 0.5661 - accuracy: 0.7185 - val_loss: 0.6364 - val_accuracy: 0.6270
# Epoch 6/15
# 100/100 [==============================] - 51s 509ms/step - loss: 0.5680 - accuracy: 0.7139 - val_loss: 0.5453 - val_accuracy: 0.7430
# Epoch 7/15
# 100/100 [==============================] - 51s 514ms/step - loss: 0.5505 - accuracy: 0.7302 - val_loss: 0.4958 - val_accuracy: 0.7811
# Epoch 8/15
# 100/100 [==============================] - 52s 519ms/step - loss: 0.5511 - accuracy: 0.7265 - val_loss: 0.5633 - val_accuracy: 0.7116
# Epoch 9/15
# 100/100 [==============================] - 51s 513ms/step - loss: 0.5452 - accuracy: 0.7348 - val_loss: 0.4904 - val_accuracy: 0.7761
# Epoch 10/15
# 100/100 [==============================] - 51s 508ms/step - loss: 0.5315 - accuracy: 0.7430 - val_loss: 0.5193 - val_accuracy: 0.7514
# Epoch 11/15
# 100/100 [==============================] - 51s 509ms/step - loss: 0.5273 - accuracy: 0.7476 - val_loss: 0.5305 - val_accuracy: 0.7374
# Epoch 12/15
# 100/100 [==============================] - 50s 502ms/step - loss: 0.5256 - accuracy: 0.7500 - val_loss: 0.5266 - val_accuracy: 0.7478
# Epoch 13/15
# 100/100 [==============================] - 51s 509ms/step - loss: 0.5060 - accuracy: 0.7635 - val_loss: 0.5414 - val_accuracy: 0.7224
# Epoch 14/15
# 100/100 [==============================] - 50s 500ms/step - loss: 0.5045 - accuracy: 0.7674 - val_loss: 0.4781 - val_accuracy: 0.7802
# Epoch 15/15
# 100/100 [==============================] - 50s 500ms/step - loss: 0.5085 - accuracy: 0.7651 - val_loss: 0.4923 - val_accuracy: 0.7682

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc2=history2.history['accuracy']
val_acc2=history2.history['val_accuracy']
loss2=history2.history['loss']
val_loss2=history2.history['val_loss']

epochs2=range(len(acc2)) # Get number of epochs

# %%
#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs2, acc2, 'r', label = "Training Accuracy")
plt.plot(epochs2, val_acc2, 'b', label = "Validation Accuracy")
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy') 
plt.legend()  

plt.show()

# %%
#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs2, loss2, 'r', label = "Training Loss")
plt.plot(epochs2, val_loss2, 'b', label = "Validation Loss")
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()  

plt.show()
# Desired output. Charts with training and validation metrics. No crash :)

# %% [markdown]
# ### Modelo 3

# %%
checkpoint3 = ModelCheckpoint('Pesos/Modelo3/pesos_del_modelo3_epoch_{epoch:02d}.h5', 
                             save_weights_only=True, 
                             save_best_only=False)

# %%
model3 = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (5, 5), activation='relu', input_shape=(50, 50, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(256, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(512, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    #tf.keras.layers.Conv2D(1024, (3, 3), activation='relu'),
    #tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(2048, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model3.compile(optimizer=RMSprop(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
history3 = model3.fit(train_generator,
                              steps_per_epoch= 100,
                              epochs=30,
                              verbose=1,
                              validation_data=validation_generator,
                              callbacks=checkpoint3)
# Out:
# Epoch 1/30
# 100/100 [==============================] - 66s 658ms/step - loss: 0.6959 - accuracy: 0.5225 - val_loss: 0.6485 - val_accuracy: 0.7078
# Epoch 2/30
# 100/100 [==============================] - 66s 660ms/step - loss: 0.6473 - accuracy: 0.6360 - val_loss: 0.5913 - val_accuracy: 0.7236
# Epoch 3/30
# 100/100 [==============================] - 64s 639ms/step - loss: 0.6153 - accuracy: 0.6729 - val_loss: 0.5665 - val_accuracy: 0.7285
# Epoch 4/30
# 100/100 [==============================] - 66s 662ms/step - loss: 0.5918 - accuracy: 0.6907 - val_loss: 0.5540 - val_accuracy: 0.7216
# Epoch 5/30
# 100/100 [==============================] - 69s 694ms/step - loss: 0.5807 - accuracy: 0.7132 - val_loss: 0.5227 - val_accuracy: 0.7620
# Epoch 6/30
# 100/100 [==============================] - 67s 669ms/step - loss: 0.5618 - accuracy: 0.7227 - val_loss: 0.5045 - val_accuracy: 0.7820
# Epoch 7/30
# 100/100 [==============================] - 70s 708ms/step - loss: 0.5598 - accuracy: 0.7300 - val_loss: 0.5290 - val_accuracy: 0.7385
# Epoch 8/30
# 100/100 [==============================] - 67s 671ms/step - loss: 0.5348 - accuracy: 0.7435 - val_loss: 0.4973 - val_accuracy: 0.7800
# Epoch 9/30
# 100/100 [==============================] - 67s 670ms/step - loss: 0.5389 - accuracy: 0.7403 - val_loss: 0.4763 - val_accuracy: 0.7894
# Epoch 10/30
# 100/100 [==============================] - 67s 675ms/step - loss: 0.5298 - accuracy: 0.7483 - val_loss: 0.4914 - val_accuracy: 0.7764
# Epoch 11/30
# 100/100 [==============================] - 67s 672ms/step - loss: 0.5163 - accuracy: 0.7519 - val_loss: 0.5984 - val_accuracy: 0.6589
# Epoch 12/30
# 100/100 [==============================] - 66s 664ms/step - loss: 0.5253 - accuracy: 0.7486 - val_loss: 0.4640 - val_accuracy: 0.7910
# Epoch 13/30
# 100/100 [==============================] - 66s 664ms/step - loss: 0.5017 - accuracy: 0.7657 - val_loss: 0.4472 - val_accuracy: 0.7965
# Epoch 14/30
# 100/100 [==============================] - 67s 671ms/step - loss: 0.5040 - accuracy: 0.7655 - val_loss: 0.5936 - val_accuracy: 0.7067
# Epoch 15/30
# 100/100 [==============================] - 68s 679ms/step - loss: 0.4883 - accuracy: 0.7726 - val_loss: 0.4406 - val_accuracy: 0.8024
# Epoch 16/30
# 100/100 [==============================] - 66s 661ms/step - loss: 0.4797 - accuracy: 0.7757 - val_loss: 0.5832 - val_accuracy: 0.6955
# Epoch 17/30
# 100/100 [==============================] - 66s 666ms/step - loss: 0.4765 - accuracy: 0.7787 - val_loss: 0.4385 - val_accuracy: 0.8008
# Epoch 18/30
#  42/100 [===========>..................] - ETA: 15s - loss: 0.4710 - accuracy: 0.7821

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc3 = history3.history['accuracy']
val_acc3 = history3.history['val_accuracy']
loss3 =history3.history['loss']
val_loss3 =history3.history['val_loss']

epochs3=range(len(acc3)) # Get number of epochs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 5
#       1 #-----------------------------------------------------------
#       2 # Retrieve a list of list results on training and test data
#       3 # sets for each training epoch
#       4 #-----------------------------------------------------------
# ----> 5 acc3 = history3.history['accuracy']
#       6 val_acc3 = history3.history['val_accuracy']
#       7 loss3 =history3.history['loss']
#
# NameError: name 'history3' is not defined

# %%
#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs3, acc3, 'r', label = "Training Accuracy")
plt.plot(epochs3, val_acc3, 'b', label = "Validation Accuracy")
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy') 
plt.legend()  

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 #------------------------------------------------
#       2 # Plot training and validation accuracy per epoch
#       3 #------------------------------------------------
# ----> 4 plt.plot(epochs2, acc2, 'r', "Training Accuracy")
#       5 plt.plot(epochs2, val_acc2, 'b', "Validation Accuracy")
#       6 plt.title('Training and validation accuracy')
#
# NameError: name 'epochs2' is not defined

# %%
#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs3, loss3, 'r', label = "Training Loss")
plt.plot(epochs3, val_loss3, 'b', label = "Validation Loss")
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()  

plt.show()
# Desired output. Charts with training and validation metrics. No crash :)

# %% [markdown]
# ### Modelo 4

# %%
checkpoint4 = ModelCheckpoint('Pesos/Modelo4/pesos_del_modelo4_epoch_{epoch:02d}.h5', 
                             save_weights_only=True, 
                             save_best_only=False)

# %%
model4 = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (2, 2), activation='relu', input_shape=(50, 50, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(256, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(1024, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model4.compile(optimizer=RMSprop(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
history4 = model4.fit(train_generator,
                              steps_per_epoch= 100,
                              epochs=100,
                              verbose=1,
                              validation_data=validation_generator,
                              callbacks=checkpoint4)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 50s 499ms/step - loss: 0.4576 - accuracy: 0.7935 - val_loss: 0.4584 - val_accuracy: 0.7914
# Epoch 2/100
# 100/100 [==============================] - 50s 500ms/step - loss: 0.4555 - accuracy: 0.7918 - val_loss: 0.4522 - val_accuracy: 0.7944
# Epoch 3/100
# 100/100 [==============================] - 49s 495ms/step - loss: 0.4385 - accuracy: 0.8092 - val_loss: 0.4328 - val_accuracy: 0.8045
# Epoch 4/100
# 100/100 [==============================] - 49s 497ms/step - loss: 0.4344 - accuracy: 0.8066 - val_loss: 0.4456 - val_accuracy: 0.8001
# Epoch 5/100
# 100/100 [==============================] - 50s 499ms/step - loss: 0.4385 - accuracy: 0.8025 - val_loss: 0.5013 - val_accuracy: 0.7619
# Epoch 6/100
# 100/100 [==============================] - 50s 498ms/step - loss: 0.4341 - accuracy: 0.8025 - val_loss: 0.4281 - val_accuracy: 0.8123
# Epoch 7/100
# 100/100 [==============================] - 49s 496ms/step - loss: 0.4327 - accuracy: 0.8086 - val_loss: 0.4256 - val_accuracy: 0.8098
# Epoch 8/100
# 100/100 [==============================] - 49s 491ms/step - loss: 0.4286 - accuracy: 0.8119 - val_loss: 0.4739 - val_accuracy: 0.7837
# Epoch 9/100
# 100/100 [==============================] - 50s 499ms/step - loss: 0.4346 - accuracy: 0.8049 - val_loss: 0.4122 - val_accuracy: 0.8209
# Epoch 10/100
# 100/100 [==============================] - 49s 491ms/step - loss: 0.4279 - accuracy: 0.8067 - val_loss: 0.4232 - val_accuracy: 0.8134
# Epoch 11/100
# 100/100 [==============================] - 49s 493ms/step - loss: 0.4106 - accuracy: 0.8173 - val_loss: 0.4460 - val_accuracy: 0.8072
# Epoch 12/100
# 100/100 [==============================] - 49s 491ms/step - loss: 0.4272 - accuracy: 0.8113 - val_loss: 0.4131 - val_accuracy: 0.8225
# Epoch 13/100
# 100/100 [==============================] - 49s 492ms/step - loss: 0.4203 - accuracy: 0.8167 - val_loss: 0.4249 - val_accuracy: 0.8061
# Epoch 14/100
# 100/100 [==============================] - 49s 490ms/step - loss: 0.4092 - accuracy: 0.8201 - val_loss: 0.4071 - val_accuracy: 0.8245
# Epoch 15/100
# 100/100 [==============================] - 49s 492ms/step - loss: 0.4246 - accuracy: 0.8095 - val_loss: 0.4684 - val_accuracy: 0.7862
# Epoch 16/100
# 100/100 [==============================] - 48s 486ms/step - loss: 0.4117 - accuracy: 0.8192 - val_loss: 0.4126 - val_accuracy: 0.8162
# Epoch 17/100
# 100/100 [==============================] - 49s 495ms/step - loss: 0.4091 - accuracy: 0.8178 - val_loss: 0.4044 - val_accuracy: 0.8247
# Epoch 18/100
# 100/100 [==============================] - 49s 488ms/step - loss: 0.4122 - accuracy: 0.8202 - val_loss: 0.3897 - val_accuracy: 0.8304
# Epoch 19/100
# 100/100 [==============================] - 49s 493ms/step - loss: 0.4116 - accuracy: 0.8171 - val_loss: 0.4060 - val_accuracy: 0.8204
# Epoch 20/100
# 100/100 [==============================] - 49s 492ms/step - loss: 0.4053 - accuracy: 0.8233 - val_loss: 0.3928 - val_accuracy: 0.8287
# Epoch 21/100
# 100/100 [==============================] - 49s 491ms/step - loss: 0.
100
# 100/100 [==============================] - 49s 491ms/step - loss: 0.3648 - accuracy: 0.8461 - val_loss: 0.3599 - val_accuracy: 0.8449
# Epoch 79/100
# 100/100 [==============================] - 48s 486ms/step - loss: 0.3731 - accuracy: 0.8378 - val_loss: 0.3739 - val_accuracy: 0.8406
# Epoch 80/100
# 100/100 [==============================] - 49s 489ms/step - loss: 0.3586 - accuracy: 0.8480 - val_loss: 0.3536 - val_accuracy: 0.8482
# Epoch 81/100
# 100/100 [==============================] - 49s 490ms/step - loss: 0.3630 - accuracy: 0.8462 - val_loss: 0.3718 - val_accuracy: 0.8396
# Epoch 82/100
# 100/100 [==============================] - 49s 493ms/step - loss: 0.3673 - accuracy: 0.8437 - val_loss: 0.3514 - val_accuracy: 0.8507
# Epoch 83/100
# 100/100 [==============================] - 49s 490ms/step - loss: 0.3783 - accuracy: 0.8378 - val_loss: 0.3711 - val_accuracy: 0.8389
# Epoch 84/100
# 100/100 [==============================] - 49s 489ms/step - loss: 0.3720 - accuracy: 0.8400 - val_loss: 0.3539 - val_accuracy: 0.8488
# Epoch 85/100
# 100/100 [==============================] - 49s 489ms/step - loss: 0.3560 - accuracy: 0.8462 - val_loss: 0.3708 - val_accuracy: 0.8398
# Epoch 86/100
# 100/100 [==============================] - 48s 486ms/step - loss: 0.3683 - accuracy: 0.8434 - val_loss: 0.3618 - val_accuracy: 0.8438
# Epoch 87/100
# 100/100 [==============================] - 49s 490ms/step - loss: 0.3654 - accuracy: 0.8424 - val_loss: 0.3797 - val_accuracy: 0.8398
# Epoch 88/100
# 100/100 [==============================] - 49s 488ms/step - loss: 0.3607 - accuracy: 0.8447 - val_loss: 0.3547 - val_accuracy: 0.8484
# Epoch 89/100
# 100/100 [==============================] - 48s 486ms/step - loss: 0.3628 - accuracy: 0.8478 - val_loss: 0.3521 - val_accuracy: 0.8506
# Epoch 90/100
# 100/100 [==============================] - 49s 490ms/step - loss: 0.3578 - accuracy: 0.8467 - val_loss: 0.3838 - val_accuracy: 0.8328
# Epoch 91/100
# 100/100 [==============================] - 49s 489ms/step - loss: 0.3540 - accuracy: 0.8504 - val_loss: 0.3844 - val_accuracy: 0.8339
# Epoch 92/100
# 100/100 [==============================] - 48s 486ms/step - loss: 0.3553 - accuracy: 0.8498 - val_loss: 0.4040 - val_accuracy: 0.8189
# Epoch 93/100
# 100/100 [==============================] - 48s 485ms/step - loss: 0.3637 - accuracy: 0.8416 - val_loss: 0.3507 - val_accuracy: 0.8507
# Epoch 94/100
# 100/100 [==============================] - 48s 486ms/step - loss: 0.3597 - accuracy: 0.8492 - val_loss: 0.3597 - val_accuracy: 0.8466
# Epoch 95/100
# 100/100 [==============================] - 49s 491ms/step - loss: 0.3490 - accuracy: 0.8495 - val_loss: 0.3711 - val_accuracy: 0.8432
# Epoch 96/100
# 100/100 [==============================] - 48s 487ms/step - loss: 0.3652 - accuracy: 0.8474 - val_loss: 0.3523 - val_accuracy: 0.8497
# Epoch 97/100
# 100/100 [==============================] - 49s 488ms/step - loss: 0.3604 - accuracy: 0.8446 - val_loss: 0.3543 - val_accuracy: 0.8529
# Epoch 98/100
# 100/100 [==============================] - 48s 485ms/step - loss: 0.3635 - accuracy: 0.8440 - val_loss: 0.3487 - val_accuracy: 0.8514
# Epoch 99/100
# 100/100 [==============================] - 48s 484ms/step - loss: 0.3611 - accuracy: 0.8449 - val_loss: 0.3387 - val_accuracy: 0.8556
# Epoch 100/100
# 100/100 [==============================] - 48s 484ms/step - loss: 0.3647 - accuracy: 0.8407 - val_loss: 0.3576 - val_accuracy: 0.8453

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc4 = history4.history['accuracy']
val_acc4 = history4.history['val_accuracy']
loss4 = history4.history['loss']
val_loss4 = history4.history['val_loss']

epochs4=range(len(acc4)) # Get number of epochs

# %%
#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs4, acc4, 'r', label = "Training Accuracy")
plt.plot(epochs4, val_acc4, 'b', label = "Validation Accuracy")
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy') 
plt.legend()  

plt.show()

# %%
#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs4, loss4, 'r', label = "Training Loss")
plt.plot(epochs4, val_loss4, 'b', label = "Validation Loss")
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()  

plt.show()
# Desired output. Charts with training and validation metrics. No crash :)

# %% [markdown]
# ## Matriz de confusión

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 acc = history.history['accuracy']
#       2 val_acc = history.history['val_accuracy']
#       3 loss = history.history['loss']
#
# NameError: name 'history' is not defined
